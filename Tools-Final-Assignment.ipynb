# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Gweneth Andersen** *(Gweneth Gray on GitHub)*
#
# Medical Physics Assistant

# %% [markdown]
# *I am interested in using data science to improve the QA workflows at my radiation oncology clinic, where we have a deluge of diagnostic imaging data and linear accelerator logs. Learning how to build reusable models to check treatment quality will help the clinic run smoothly when I am gone (implementing them at some other clinic).*

# %% [markdown]
# ### The following code demonstrates how to use the "walrus operator"

# %%
walrus = False
actually = (walrus := True)
actually
# Out:
# True

# %% [markdown]
# ---
#
# Recipe for <s>Disaster</s> <a href="https://www.amazon.com/Trader-Joes-Gluten-Apple-Coconut/dp/B00SNT2XXM">Trader Joe's Gluten Free Apple + Coconut Fruit Bar</a>:
#
# * Apple
# * Coconut
#
# <blockquote><p><i>"Yum! It's sitting on my desk right in front of me!"</i></p></blockquote>
#
# <img src="https://2.bp.blogspot.com/-ZfjM_wSOAuQ/VtR309HZ1MI/AAAAAAAAGOk/CxVLPklVwlI/s1600/APCOCO.jpg">
